# %%
# !pip install pyarrow
# !pip install fastparquet
# Out:
# Requirement already satisfied: pyarrow in c:\programdata\anaconda3\lib\site-packages (11.0.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\programdata\anaconda3\lib\site-packages (from pyarrow) (1.23.5)
# Requirement already satisfied: fastparquet in c:\programdata\anaconda3\lib\site-packages (2023.2.0)
# Requirement already satisfied: pandas>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from fastparquet) (1.5.3)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from fastparquet) (2022.11.0)
# Requirement already satisfied: numpy>=1.20.3 in c:\programdata\anaconda3\lib\site-packages (from fastparquet) (1.23.5)
# Requirement already satisfied: cramjam>=2.3 in c:\programdata\anaconda3\lib\site-packages (from fastparquet) (2.6.2)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from fastparquet) (22.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.5.0->fastparquet) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->fastparquet) (1.16.0)

# %%
import datetime
import warnings

import numpy as np
import pandas as pd


def set_up_printing():
    """Sets up display parameters"""

    max_dimensions_display_limit = 1000
    pd.set_option('display.max_columns', max_dimensions_display_limit)
    pd.set_option('display.max_colwidth', None)

    pd.set_option('display.max_rows', max_dimensions_display_limit)
    pd.set_option('display.width', None)

    pd.set_option('display.max_info_columns', max_dimensions_display_limit)
    pd.set_option('display.max_info_rows', max_dimensions_display_limit)

    warnings.filterwarnings('ignore')


def log_status(msg, is_log_enabled):
    if is_log_enabled:
        print(datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S"), msg)


def groupby_then_apply(dataframe, key_col_name, func, part_size=100):
    parts = np.array_split(dataframe, part_size)

    print(datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S"), 'всего задач для процессинга: ', str(len(parts)))

    results = []
    outliers = pd.DataFrame()

    print(datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S"), 'запуск цикла обработки по частям')

    logging_aux_counter = 0
    is_logging_enabled_for_cycle = True

    i = 1
    for part in parts:

        if not is_logging_enabled_for_cycle and logging_aux_counter / len(parts) > 0.003:
            is_logging_enabled_for_cycle = True
            log_status('.. выполнено ' + str(i) + ' из ' + str(len(parts)) + ' задач', is_logging_enabled_for_cycle)
            logging_aux_counter = 0

        log_status('обработка задачи ' + str(i), is_logging_enabled_for_cycle)

        part = pd.concat((outliers, part))

        last_val = part[key_col_name].iloc[-1]
        is_outlier = part[key_col_name] == last_val
        part, outliers = part[~is_outlier], part[is_outlier]

        log_status('размерность задачи до one hot encoding: ' + str(part.shape), is_logging_enabled_for_cycle)
        part = pd.get_dummies(part, columns=['activity'], sparse=True)

        log_status('размерность задачи после one hot encoding: ' + str(part.shape), is_logging_enabled_for_cycle)

        results.append(func(part))

        i = i + 1

        logging_aux_counter = logging_aux_counter + 1
        is_logging_enabled_for_cycle = False

    if len(outliers):
        log_status('обработка последней задачи вне тела цикла', True)
        outliers = pd.get_dummies(outliers, columns=['activity'], sparse=True)
        results.append(func(outliers))

    return pd.concat(results)


def agg(part):
    return part.groupby('user_id', sort=False)[part.columns.tolist()[1:]].sum()


# настроим отображение при выводе в консоль
set_up_printing()

log_status('чтение и очистка данных', True)

# считаем данные и одновременно удалим пустые строки
dataframe = pd.read_parquet(r'C:\Users\M_N_K\kosta_2023_dataton\train_mfti.parquet')

dataframe = dataframe.drop_duplicates()

dataframe = dataframe[dataframe['event_type'].isin(['click_phone','click_response'])]
dataframe = dataframe.groupby('user_id').filter(lambda x: len(x)>30)

dataframe['user_id'] = dataframe['user_id'].fillna(dataframe['cookie_id'])
dataframe['activity'] = dataframe['vacancy_id_'].astype(str) + '_' + dataframe['event_type'].astype(str)
dataframe = dataframe[['user_id', 'activity']]

dataframe = dataframe.sort_values(by='user_id')

log_status('обработка по частям', True)

print('\n')
dataframe.info()
print('\n')

results = groupby_then_apply(
    dataframe,
    key_col_name='user_id',
    func=agg,
    part_size=int(dataframe.shape[0] / 1000)
)

results = results.sparse.to_dense().fillna(0)

log_status('размерность итогового набора после векторизации: ' + str(results.shape), True)

log_status('запись в файл', True)

results.to_parquet(r'C:\Users\M_N_K\kosta_2023_dataton\KNN_users_vectors_min.parquet', index=True)

log_status('результат записан в файловую систему', True)
# Out:
# 30/04/2023 01:40:13 чтение и очистка данных
# 30/04/2023 01:40:27 обработка по частям
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27310 entries, 11715796 to 11775669
# Data columns (total 2 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   object
#  1   activity  object
# dtypes: object(2)
# memory usage: 640.1+ KB
#
#
# 30/04/2023 01:40:27 всего задач для процессинга:  27
# 30/04/2023 01:40:27 запуск цикла обработки по частям
# 30/04/2023 01:40:27 обработка задачи 1
# 30/04/2023 01:40:27 размерность задачи до one hot encoding: (1006, 2)
# 30/04/2023 01:40:27 размерность задачи после one hot encoding: (1006, 789)
# 30/04/2023 01:40:29 .. выполнено 2 из 27 задач
# 30/04/2023 01:40:29 обработка задачи 2
# 30/04/2023 01:40:29 размерность задачи до one hot encoding: (989, 2)
# 30/04/2023 01:40:29 размерность задачи после one hot encoding: (989, 779)
# 30/04/2023 01:40:31 .. выполнено 3 из 27 задач
# 30/04/2023 01:40:31 обработка задачи 3
# 30/04/2023 01:40:31 размерность задачи до one hot encoding: (1027, 2)
# 30/04/2023 01:40:31 размерность задачи после one hot encoding: (1027, 849)
# 30/04/2023 01:40:33 .. выполнено 4 из 27 задач
# 30/04/2023 01:40:33 обработка задачи 4
# 30/04/2023 01:40:33 размерность задачи до one hot encoding: (986, 2)
# 30/04/2023 01:40:33 размерность задачи после one hot encoding: (986, 780)
# 30/04/2023 01:40:34 .. выполнено 5 из 27 задач
# 30/04/2023 01:40:34 обработка задачи 5
# 30/04/2023 01:40:34 размерность задачи до one hot encoding: (1049, 2)
# 30/04/2023 01:40:34 размерность задачи после one hot encoding: (1049, 785)
# 30/04/2023 01:40:36 .. выполнено 6 из 27 задач
# 30/04/2023 01:40:36 обработка задачи 6
# 30/04/2023 01:40:36 размерность задачи до one hot encoding: (984, 2)
# 30/04/2023 01:40:36 размерность задачи после one hot encoding: (984, 726)
# 30/04/2023 01:40:37 .. выполнено 7 из 27 задач
# 30/04/2023 01:40:37 обработка задачи 7
# 30/04/2023 01:40:37 размерность задачи до one hot encoding: (1039, 2)
# 30/04/2023 01:40:37 размерность задачи после one hot encoding: (1039, 871)
# 30/04/2023 01:40:39 .. выполнено 8 из 27 задач
# 30/04/2023 01:40:39 обработка задачи 8
# 30/04/2023 01:40:39 размерность задачи до one hot encoding: (1006, 2)
# 30/04/2023 01:40:39 размерность задачи после one hot encoding: (1006, 795)
# 30/04/2023 01:40:40 .. выполнено 9 из 27 задач
# 30/04/2023 01:40:40 обработка задачи 9
# 30/04/2023 01:40:40 размерность задачи до one hot encoding: (1016, 2)
# 30/04/2023 01:40:40 размерность задачи после one hot encoding: (1016, 804)
# 30/04/2023 01:40:42 .. выполнено 10 из 27 задач
# 30/04/2023 01:40:42 обработка задачи 10
# 30/04/2023 01:40:42 размерность задачи до one hot encoding: (1010, 2)
# 30/04/2023 01:40:42 размерность задачи после one hot encoding: (1010, 855)
# 30/04/2023 01:40:44 .. выполнено 11 из 27 задач
# 30/04/2023 01:40:44 обработка задачи 11
# 30/04/2023 01:40:44 размерность задачи до one hot encoding: (997, 2)
# 30/04/2023 01:40:44 размерность задачи после one hot encoding: (997, 791)
# 30/04/2023 01:40:46 .. выполнено 12 из 27 задач
# 30/04/2023 01:40:46 обработка задачи 12
# 30/04/2023 01:40:46 размерность задачи до one hot encoding: (1011, 2)
# 30/04/2023 01:40:46 размерность задачи после one hot encoding: (1011, 853)
# 30/04/2023 01:40:48 .. выполнено 13 из 27 задач
# 30/04/2023 01:40:48 обработка задачи 13
# 30/04/2023 01:40:48 размерность задачи до one hot encoding: (1012, 2)
# 30/04/2023 01:40:48 размерность задачи после one hot encoding: (1012, 830)
# 30/04/2023 01:40:50 .. выполнено 14 из 27 задач
# 30/04/2023 01:40:50 обработка задачи 14
# 30/04/2023 01:40:50 размерность задачи до one hot encoding: (1012, 2)
# 30/04/2023 01:40:50 размерность задачи после one hot encoding: (1012, 833)
# 30/04/2023 01:40:52 .. выполнено 15 из 27 задач
# 30/04/2023 01:40:52 обработка задачи 15
# 30/04/2023 01:40:52 размерность задачи до one hot encoding: (1009, 2)
# 30/04/2023 01:40:52 размерность задачи после one hot encoding: (1009, 802)
# 30/04/2023 01:40:54 .. выполнено 16 из 27 задач
# 30/04/2023 01:40:54 обработка задачи 16
# 30/04/2023 01:40:54 размерность задачи до one hot encoding: (1021, 2)
# 30/04/2023 01:40:54 размерность задачи после one hot encoding: (1021, 808)
# 30/04/2023 01:40:55 .. выполнено 17 из 27 задач
# 30/04/2023 01:40:55 обработка задачи 17
# 30/04/2023 01:40:55 размерность задачи до one hot encoding: (976, 2)
# 30/04/2023 01:40:55 размерность задачи после one hot encoding: (976, 805)
# 30/04/2023 01:40:57 .. выполнено 18 из 27 задач
# 30/04/2023 01:40:57 обработка задачи 18
# 30/04/2023 01:40:57 размерность задачи до one hot encoding: (1050, 2)
# 30/04/2023 01:40:57 размерность задачи после one hot encoding: (1050, 902)
# 30/04/2023 01:40:59 .. выполнено 19 из 27 задач
# 30/04/2023 01:40:59 обработка задачи 19
# 30/04/2023 01:40:59 размерность задачи до one hot encoding: (966, 2)
# 30/04/2023 01:40:59 размерность задачи после one hot encoding: (966, 807)
# 30/04/2023 01:41:01 .. выполнено 20 из 27 задач
# 30/04/2023 01:41:01 обработка задачи 20
# 30/04/2023 01:41:01 размерность задачи до one hot encoding: (958, 2)
# 30/04/2023 01:41:01 размерность задачи после one hot encoding: (958, 789)
# 30/04/2023 01:41:02 .. выполнено 21 из 27 задач
# 30/04/2023 01:41:02 обработка задачи 21
# 30/04/2023 01:41:02 размерность задачи до one hot encoding: (1114, 2)
# 30/04/2023 01:41:02 размерность задачи после one hot encoding: (1114, 777)
# 30/04/2023 01:41:03 .. выполнено 22 из 27 задач
# 30/04/2023 01:41:03 обработка задачи 22
# 30/04/2023 01:41:03 размерность задачи до one hot encoding: (984, 2)
# 30/04/2023 01:41:03 размерность задачи после one hot encoding: (984, 793)
# 30/04/2023 01:41:05 .. выполнено 23 из 27 задач
# 30/04/2023 01:41:05 обработка задачи 23
# 30/04/2023 01:41:05 размерность задачи до one hot encoding: (1024, 2)
# 30/04/2023 01:41:05 размерность задачи после one hot encoding: (1024, 749)
# 30/04/2023 01:41:06 .. выполнено 24 из 27 задач
# 30/04/2023 01:41:06 обработка задачи 24
# 30/04/2023 01:41:06 размерность задачи до one hot encoding: (1017, 2)
# 30/04/2023 01:41:06 размерность задачи после one hot encoding: (1017, 865)
# 30/04/2023 01:41:08 .. выполнено 25 из 27 задач
# 30/04/2023 01:41:08 обработка задачи 25
# 30/04/2023 01:41:08 размерность задачи до one hot encoding: (1023, 2)
# 30/04/2023 01:41:08 размерность задачи после one hot encoding: (1023, 818)
# 30/04/2023 01:41:10 .. выполнено 26 из 27 задач
# 30/04/2023 01:41:10 обработка задачи 26
# 30/04/2023 01:41:10 размерность задачи до one hot encoding: (961, 2)
# 30/04/2023 01:41:10 размерность задачи после one hot encoding: (961, 789)
# 30/04/2023 01:41:12 .. выполнено 27 из 27 задач
# 30/04/2023 01:41:12 обработка задачи 27
# 30/04/2023 01:41:12 размерность задачи до one hot encoding: (877, 2)
# 30/04/2023 01:41:12 размерность задачи после one hot encoding: (877, 717)
# 30/04/2023 01:41:13 обработка последней задачи вне тела цикла
# 30/04/2023 01:42:13 размерность итогового набора после векторизации: (582, 14698)
# 30/04/2023 01:42:13 запись в файл
# 30/04/2023 01:42:15 результат записан в файловую систему

# %%
check_df = pd.read_parquet(r'C:\Users\M_N_K\kosta_2023_dataton\KNN_users_vectors_min.parquet')
check_df.info(max_cols=100)
check_df[check_df.columns.tolist()[:10]].head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 582 entries, 0066831bd3cf418ba2714b09de355389 to ff86f10a411d478da7e0653319c747b0
# Columns: 14698 entries, activity_100285_click_response to activity_258325_click_phone
# dtypes: float64(14698)
# memory usage: 65.3+ MB
#                                   activity_100285_click_response  \
# user_id
# 0066831bd3cf418ba2714b09de355389                             0.0
# 00c841230129452eada20720659ae3c0                             0.0
# 010e886447c14fb191a497df20713932                             0.0
# 0138f1289dcc442eb37624a6950d6178                             0.0
# 01860ee97b034f9bae74ed183110bc2f                             0.0
# 01b6c1228ed645faa5145785392e8296                             0.0
# 01df285b34cb439eac90d0fee9c0b60f                             0.0
# 02911d50ee4b4f938daa378ec05128d3                             0.0
# 048d3eb16c2e41379d42376565b8e7b4                             0.0
# 049235e0c99f49ed8043bdbca8c802e1                             0.0
#
#                                   activity_100501_click_response  \
# user_id
# 0066831bd3cf418ba2714b09de355389                             0.0
# 00c841230129452eada20720659ae3c0                             0.0
# 010e886447c14fb191a497df20713932                             0.0
# 0138f1289dcc442eb37624a6950d6178                             0.0
# 01860ee97b034f9bae74ed183110bc2f                             0.0
# 01b6c1228ed645faa5145785392e8296                             0.0
# 01df285b34cb439eac90d0fee9c0b60f                             0.0
# 02911d50ee4b4f938daa378ec05128d3                             0.0
# 048d3eb16c2e41379d42376565b8e7b4                             0.0
# 049235e0c99f49ed8043bdbca8c802e1                             0.0
#
#                                   activity_101097_click_phone  \
# user_id
# 0066831bd3cf418ba2714b09de355389                          0.0
# 00c841230129452eada20720659ae3c0                          0.0
# 010e886447c14fb191a497df20713932                          0.0
# 0138f1289dcc442eb37624a6950d6178                          0.0
# 01860ee97b034f9bae74ed183110bc2f                          0.0
# 01b6c1228ed645faa5145785392e8296                          0.0
# 01df285b34cb439eac90d0fee9c0b60f                          0.0
# 02911d50ee4b4f938daa378ec05128d3                          0.0
# 048d3eb16c2e41379d42376565b8e7b4                          0.0
# 049235e0c99f49ed8043bdbca8c802e1                          0.0
#
#                                   activity_101097_click_response  \
# user_id
# 0066831bd3cf418ba2714b09de355389                             0.0
# 00c841230129452eada20720659ae3c0                             0.0
# 010e886447c14fb191a497df20713932                             0.0
# 0138f1289dcc442eb37624a6950d6178                             0.0
# 01860ee97b034f9bae74ed183110bc2f                             0.0
# 01b6c1228ed645faa5145785392e8296                             0.0
# 01df285b34cb439eac90d0fee9c0b60f                             0.0
# 02911d50ee4b4f938daa378ec05128d3                             0.0
# 048d3eb16c2e41379d42376565b8e7b4                             0.0
# 049235e0c99f49ed8043bdbca8c802e1                             0.0
#
#                                   activity_101462_click_response  \
# user_id
# 0066831bd3cf418ba2714b09de355389                             0.0
# 00c841230129452eada20720659ae3c0                             0.0
# 010e886447c14fb191a497df20713932                             0.0
# 0138f1289dcc442eb37624a6950d6178                             0.0
# 01860ee97b034f9bae74ed183110bc2f                             0.0
# 01b6c1228ed645faa5145785392e8296                             0.0
# 01df285b34cb439eac90d0fee9c0b60f                             0.0
# 02911d50ee4b4f938daa378ec05128d3                             0.0
# 048d3eb16c2e41379d42376565b8e7b4                             0.0
# 049235e0c99f49ed8043bdbca8c802e1                             0.0
#
#                                   activity_101487_click_response  \
# user_id
# 0066831bd3cf418ba2714b09de355389                             0.0
# 00c841230129452eada20720659ae3c0                             0.0
# 010e886447c14fb191a497df20713932                             0.0
# 0138f1289dcc442eb37624a6950d6178                             0.0
# 01860ee97b034f9bae74ed183110bc2f                             0.0
# 01b6c1228ed645faa5145785392e8296                             0.0
# 01df285b34cb439eac90d0fee9c0b60f                             0.0
# 02911d50ee4b4f938daa378ec05128d3                             0.0
# 048d3eb16c2e41379d42376565b8e7b4                             0.0
# 049235e0c99f49ed8043bdbca8c802e1                             0.0
#
#                                   activity_101650_click_response  \
# user_id
# 0066831bd3cf418ba2714b09de355389                             0.0
# 00c841230129452eada20720659ae3c0                             0.0
# 010e886447c14fb191a497df20713932                             0.0
# 0138f1289dcc442eb37624a6950d6178                             0.0
# 01860ee97b034f9bae74ed183110bc2f                             0.0
# 01b6c1228ed645faa5145785392e8296                             0.0
# 01df285b34cb439eac90d0fee9c0b60f                             0.0
# 02911d50ee4b4f938daa378ec05128d3                             0.0
# 048d3eb16c2e41379d42376565b8e7b4                             0.0
# 049235e0c99f49ed8043bdbca8c802e1                             0.0
#
#                                   activity_101687_click_response  \
# user_id
# 0066831bd3cf418ba2714b09de355389                             0.0
# 00c841230129452eada20720659ae3c0                             0.0
# 010e886447c14fb191a497df20713932                             0.0
# 0138f1289dcc442eb37624a6950d6178                             0.0
# 01860ee97b034f9bae74ed183110bc2f                             1.0
# 01b6c1228ed645faa5145785392e8296                             0.0
# 01df285b34cb439eac90d0fee9c0b60f                             0.0
# 02911d50ee4b4f938daa378ec05128d3                             0.0
# 048d3eb16c2e41379d42376565b8e7b4                             0.0
# 049235e0c99f49ed8043bdbca8c802e1                             0.0
#
#                                   activity_101822_click_phone  \
# user_id
# 0066831bd3cf418ba2714b09de355389                          0.0
# 00c841230129452eada20720659ae3c0                          0.0
# 010e886447c14fb191a497df20713932                          0.0
# 0138f1289dcc442eb37624a6950d6178                          0.0
# 01860ee97b034f9bae74ed183110bc2f                          0.0
# 01b6c1228ed645faa5145785392e8296                          0.0
# 01df285b34cb439eac90d0fee9c0b60f                          1.0
# 02911d50ee4b4f938daa378ec05128d3                          0.0
# 048d3eb16c2e41379d42376565b8e7b4                          0.0
# 049235e0c99f49ed8043bdbca8c802e1                          0.0
#
#                                   activity_101943_click_response
# user_id
# 0066831bd3cf418ba2714b09de355389                             0.0
# 00c841230129452eada20720659ae3c0                             0.0
# 010e886447c14fb191a497df20713932                             0.0
# 0138f1289dcc442eb37624a6950d6178                             0.0
# 01860ee97b034f9bae74ed183110bc2f                             0.0
# 01b6c1228ed645faa5145785392e8296                             0.0
# 01df285b34cb439eac90d0fee9c0b60f                             0.0
# 02911d50ee4b4f938daa378ec05128d3                             0.0
# 048d3eb16c2e41379d42376565b8e7b4                             0.0
# 049235e0c99f49ed8043bdbca8c802e1                             0.0
